# %% [markdown]
# ## Load Dataset

# %%
import pandas as pd

adj_close_df = pd.read_csv("../data/raw/adj_close_prices.csv", index_col=0, parse_dates=True)

# %% [markdown]
# ## Check Format of Dataset

# %%
adj_close_df.shape
# Out:
# (2012, 43)

# %%
adj_close_df.head()
# Out:
#                   AAL       AAPL        ADBE        ALGT        ALK  \
# Date
# 2017-01-03  44.741234  26.721243  103.480003  150.641678  82.679192
# 2017-01-04  45.127769  26.691328  104.139999  154.042679  83.787849
# 2017-01-05  44.345028  26.827070  105.910004  153.090408  82.453728
# 2017-01-06  44.654263  27.126141  108.300003  150.868423  81.720886
# 2017-01-09  45.494976  27.374603  108.570000  152.818314  82.181244
#
#                   BAC        BBY         BK          C        COF  ...  \
# Date                                                               ...
# 2017-01-03  18.275875  30.225380  37.476257  45.227501  75.335953  ...
# 2017-01-04  18.616575  30.939327  38.062313  45.839592  76.548187  ...
# 2017-01-05  18.397551  30.140568  37.577839  45.040894  74.920578  ...
# 2017-01-06  18.397551  30.232452  37.640339  45.197636  75.107079  ...
# 2017-01-09  18.292099  30.635366  37.226196  44.951313  74.123726  ...
#
# ...

# %% [markdown]
# ## Check for Missing Values

# %%
adj_close_df.isna().sum()
# Out:
# AAL      0
# AAPL     0
# ADBE     0
# ALGT     0
# ALK      0
# BAC      0
# BBY      0
# BK       0
# C        0
# COF      0
# COST     0
# CRM      0
# CSCO     0
# DAL      0
# DG       0
# DLTR     0
# GOOGL    0
# GS       0
# HD       0
# IBM      0
# INTC     0
# JBLU     0
# JPM      0
# KR       0
# LOW      0
# LUV      0
# META     0
# MS       0
# MSFT     0
# NVDA     0
# ORCL     0
# PNC      0
# ROST     0
# SCHW     0
# SKYW     0
# TFC      0
# TGT      0
# TJX      0
# TXN      0
# UAL      0
# USB      0
# WFC      0
# WMT      0
# dtype: int64

# %%
adj_close_df.isna().sum().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Visualize Sample Price Series

# %%
adj_close_df[["JPM", "BAC"]].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
adj_close_df[["AAPL", "MSFT"]].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
adj_close_df[["AAL", "LUV"]].plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## Save Cleaned Dataset

# %%
adj_close_df.to_csv("../data/processed/adj_close_prices.csv")
